# %%
import pandas as pd 
import numpy as np
import os 
import sys
sys.path.append('./../../.')
sys.path.append('./../.')
import glob 
from tqdm import tqdm 
import joblib
from joblib import Parallel, delayed
from pandarallel import pandarallel
pandarallel.initialize()
import re
import yaml
from collections import Counter

import pickle

DATA_SOURCE = './../data/'
CONFIG = None
DIR_LOC = None
CONFIG = None
CONFIG_FILE = 'config.yaml'
id_col = 'PanjivaRecordID'
ns_id_col = 'NegSampleID'
num_neg_samples_ape = None
use_cols = None
freq_bound = None
column_value_filters = None
num_neg_samples = None
save_dir = None
NUMERIC_COLUMNS = None
DISCRETE_COLUMNS = None


def set_up_config(_DIR = None):
    global DIR
    global CONFIG
    global CONFIG_FILE
    global use_cols
    global freq_bound
    global num_neg_samples_ape
    global save_dir
    global column_value_filters
    global num_neg_samples
    global DATA_SOURCE
    global DIR_LOC
    global NUMERIC_COLUMNS
    global id_col
    global DISCRETE_COLUMNS
    
    with open(CONFIG_FILE) as f:
        CONFIG = yaml.safe_load(f)

    if _DIR is not None:
        DIR = _DIR
        CONFIG['DIR'] = _DIR
    else:
        DIR = CONFIG['DIR']

    DIR_LOC = re.sub('[0-9]', '', DIR)
    DATA_SOURCE = os.path.join('./../data/', DIR_LOC)
    save_dir =  CONFIG['save_dir']
    
    if not os.path.exists(save_dir):
        os.mkdir(save_dir)
    save_dir = os.path.join(
        CONFIG['save_dir'],
        DIR
    )

    if not os.path.exists(save_dir):
        os.mkdir(save_dir)
        

    use_cols = CONFIG[DIR]['use_cols']
    freq_bound = CONFIG[DIR]['low_freq_bound']
    column_value_filters = CONFIG[DIR]['column_value_filters']
    num_neg_samples = CONFIG[DIR]['num_neg_samples']
    NUMERIC_COLUMNS = CONFIG[DIR]['numeric_columns']
    _cols = list(use_cols)
    _cols.remove(id_col)
    for nc in NUMERIC_COLUMNS:
        _cols.remove(nc)
        
    DISCRETE_COLUMNS = list(sorted(_cols))
    return 

    


def get_regex(_type):
    global DIR
    if DIR == 'us_import1':
        if _type == 'train':
            return '.*01_2015.csv'
        if _type == 'test':
            return '.*02_2015.csv'

    if DIR == 'us_import2':
        if _type == 'train':
            return '.*03_2016.csv'
        if _type == 'test':
            return '.*04_2016.csv'

    if DIR == 'us_import3':
        if _type == 'train':
            return '.*05_2016.csv'
        if _type == 'test':
            return '.*06_2016.csv'
    return '*.csv'

def get_files(DIR, _type='all'):
    global DATA_SOURCE
    data_dir = DATA_SOURCE

    regex = get_regex(_type)
    c = glob.glob(os.path.join(data_dir, '*'))

    def glob_re(pattern, strings):
        return filter(re.compile(pattern).match, strings)

    files = sorted([_ for _ in glob_re(regex, c)])

    print('DIR ::', DIR, ' Type ::', _type, 'Files count::', len(files))
    return files

def remove_low_frequency_values(df):
    global id_col
    global freq_bound
    global NUMERIC_COLUMNS
    global DISCRETE_COLUMNS
    freq_column_value_filters = {}
   
    feature_cols = list(DISCRETE_COLUMNS)
    print ('feature columns ::' , feature_cols)
    # ----
    # figure out which entities are to be removed
    # ----
    
    counter_df = pd.DataFrame(columns=['domain', 'count'])
    for c in feature_cols:
        count = len(set(df[c]))
        counter_df = counter_df.append({
            'domain': c, 'count': count
        }, ignore_index=True)
        z = np.percentile(
            list(Counter(df[c]).values()), 5)
        print(c, count, z)

    counter_df = counter_df.sort_values(by=['count'], ascending=True)
    print(counter_df)
    
    for c in list(counter_df['domain']):
        
        values = list(df[c])
        freq_column_value_filters[c] = []
        obj_counter = Counter(values)

        for _item, _count in obj_counter.items():
            if _count < freq_bound:
                freq_column_value_filters[c].append(_item)

    print('Removing :: ')
    for c, _items in freq_column_value_filters.items():
        print('column : ', c, 'count', len(_items))

    print(' DF length : ', len(df))
    for col, val in freq_column_value_filters.items():
        df = df.loc[~df[col].isin(val)]

    print(' DF length : ', len(df))
    return df

def apply_value_filters(list_df):
    global column_value_filters

    if type(column_value_filters) != bool:
        list_processed_df = []
        for df in list_df:
            for col, val in column_value_filters.items():
                df = df.loc[~df[col].isin(val)]
            list_processed_df.append(df)
        return list_processed_df
    return list_df

def HSCode_cleanup_aux(val):
    val = val.split(';')
    val = str(val[0])
    val = val.replace('.','')
    val = str(val[:6])
    if val[:2] == '44': return val
    _list =['9401','9403','9201','9614','9202','9302', '9304', '0305', '8211', '6602','8201','9207','9504', '9205', '9206', '9209''9202']
    if val[:4] in _list: return val 
    return val

def HSCode_cleanup(list_df):
    new_list = []
    for _df in list_df :
        _df['HSCode'] = _df['HSCode'].parallel_apply(HSCode_cleanup_aux)
        _df = _df.dropna()
        print(' In HSCode clean up , length of dataframe ', len(_df))
        new_list.append(_df)
    return new_list




def clean_train_data():
    global DIR
    global CONFIG
    global DIR_LOC
    
    files = get_files(DIR, 'train')
    print('Columns read ', use_cols)
    list_df = [pd.read_csv(_file, usecols=use_cols, low_memory=False) for _file in files]
    list_df = [_.dropna() for _  in list_df]
    list_df = HSCode_cleanup(list_df)
    list_df_1 = apply_value_filters(list_df)
    master_df = None
    
    for df in list_df_1:
        if master_df is None:
            master_df = pd.DataFrame(df, copy=True)
        else:
            master_df = master_df.append(
                df,
                ignore_index=True
            )
    master_df = remove_low_frequency_values(master_df)
    return master_df

def order_cols(df):
    global NUMERIC_COLUMNS
    global DISCRETE_COLUMNS
    global id_col
    ord_cols = [id_col] + DISCRETE_COLUMNS + NUMERIC_COLUMNS
    return df[ord_cols]

def convert_to_ids(
        df,
        save_dir
):
    global id_col
    global freq_bound
    global DISCRETE_COLUMNS

    feature_columns = list(sorted(DISCRETE_COLUMNS))
    dict_DomainDims = {}
    col_val2id_dict = {}

    for col in feature_columns:
        vals = list(set(df[col]))
        vals = list(sorted(vals))

        id2val_dict = {
            e[0]: e[1]
            for e in enumerate(vals, 0)
        }
        print(' > ',col ,':', len(id2val_dict))

        val2id_dict = {
            v: k for k, v in id2val_dict.items()
        }
        col_val2id_dict[col] = val2id_dict


        # Replace
        df[col] = df.parallel_apply(
            replace_attr_with_id,
            axis=1,
            args=(
                col,
                val2id_dict,
            )
        )

        dict_DomainDims[col] = len(id2val_dict)

    print(' Feature columns :: ', feature_columns)
    print(' dict_DomainDims ', dict_DomainDims)

    # -------------
    # Save the domain dimensions
    # -------------

    file = 'domain_dims.pkl'
    if not os.path.exists(save_dir):
        os.mkdir(save_dir)
    f_path = os.path.join(save_dir, file)

    with open(f_path, 'wb') as fh:
        pickle.dump(
            dict_DomainDims,
            fh,
            pickle.HIGHEST_PROTOCOL
        )

    file = 'col_val2id_dict.pkl'
    f_path = os.path.join(save_dir, file)

    with open(f_path, 'wb') as fh:
        pickle.dump(
            col_val2id_dict,
            fh,
            pickle.HIGHEST_PROTOCOL
        )

    return df, col_val2id_dict

def replace_attr_with_id(row, attr, val2id_dict):
    val = row[attr]
    if val not in val2id_dict.keys():
        print(attr, val)
        return None
    else:
        return val2id_dict[val]




def setup_testing_data(
        test_df,
        train_df,
        col_val2id_dict
):
    global id_col
    global save_dir
    global DISCRETE_COLUMNS
    test_df = test_df.dropna()

    # Replace with None if ids are not in train_set
    feature_cols = list(DISCRETE_COLUMNS)
   
    for col in feature_cols:
        valid_items = list(col_val2id_dict[col].keys())
        test_df = test_df.loc[test_df[col].isin(valid_items)]

    # First convert to to ids
    for col in feature_cols:
        val2id_dict = col_val2id_dict[col]
        test_df[col] = test_df.parallel_apply(
            replace_attr_with_id,
            axis=1,
            args=(
                col,
                val2id_dict,
            )
        )
    test_df = test_df.dropna()
    test_df = test_df.drop_duplicates()
    test_df = order_cols(test_df)

    print(' Length of testing data', len(test_df))
    test_df = order_cols(test_df)
    return test_df

def create_train_test_sets():
    global use_cols
    global DIR
    global save_dir
    global column_value_filters
    global CONFIG
    global DIR_LOC
    global NUMERIC_COLUMNS
    
    train_df_file = os.path.join(save_dir, 'train_data.csv')
    test_df_file = os.path.join(save_dir, 'test_data.csv')
    column_valuesId_dict_file = 'column_valuesId_dict.pkl'
    column_valuesId_dict_path = os.path.join(save_dir, column_valuesId_dict_file)
    
    # --- Later on - remove using the saved file ---- #
    if os.path.exists(train_df_file) and os.path.exists(test_df_file) and False:
        train_df = pd.read_csv(train_df_file)
        test_df = pd.read_csv(test_df_file)
        with open(column_valuesId_dict_path, 'rb') as fh:
            col_val2id_dict = pickle.load(fh)

        return train_df, test_df, col_val2id_dict

    train_df = clean_train_data()
    train_df = order_cols(train_df)
    train_df, col_val2id_dict = convert_to_ids(
        train_df,
        save_dir
    )
    print('Length of train data ', len(train_df))
    train_df = order_cols(train_df)

    '''
         test data preprocessing
    '''
    # combine test data into 1 file :
    test_files = get_files(DIR, 'test')
    list_test_df = [
        pd.read_csv(_file, low_memory=False, usecols=use_cols)
        for _file in test_files
    ]
    list_test_df = [_.dropna() for _ in list_test_df]
    list_test_df = HSCode_cleanup(list_test_df)

    test_df = None
    for _df in list_test_df:
        if test_df is None:
            test_df = _df
        else:
            test_df = test_df.append(_df)

    print('size of  Test set ', len(test_df))
    test_df = setup_testing_data(
        test_df,
        train_df,
        col_val2id_dict
    )

    test_df.to_csv(test_df_file, index=False)
    train_df.to_csv(train_df_file, index=False)
    
    # Save data_dimensions.csv ('column', dimension')
    dim_df = pd.DataFrame(columns=['column','dimension'])
    for col in DISCRETE_COLUMNS:
        _count = len(col_val2id_dict[col])
        dim_df = dim_df.append({'column':col, 'dimension': _count},ignore_index=True
        )
        
    dim_df.to_csv(os.path.join(save_dir, 'data_dimensions.csv'), index=False)
        
    # -----------------------
    # Save col_val2id_dict
    # -----------------------
    with open(column_valuesId_dict_path, 'wb') as fh:
        pickle.dump(col_val2id_dict, fh, pickle.HIGHEST_PROTOCOL)

    return train_df, test_df, col_val2id_dict

# ================================= # 
# parser = argparse.ArgumentParser()
# parser.add_argument(
#     '--DIR', choices=['us_import1', 'us_import2', 'us_import3' ],
#     default= 'us_import2'
# )

# args = parser.parse_args()
# DIR = args.DIR
# -------------------------------- #
DIR = 'us_import3'
set_up_config(DIR)
create_train_test_sets()
# Out:
# INFO: Pandarallel will run on 40 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# DIR :: us_import3  Type :: train Files count:: 1
# Columns read  ['PanjivaRecordID', 'ConsigneePanjivaID', 'ShipperPanjivaID', 'Carrier', 'ShipmentOrigin', 'ShipmentDestination', 'PortOfUnlading', 'PortOfLading', 'HSCode', 'VolumeTEU', 'WeightKg', 'ValueOfGoodsUSD']
#  In HSCode clean up , length of dataframe  238417
# feature columns :: ['Carrier', 'ConsigneePanjivaID', 'HSCode', 'PortOfLading', 'PortOfUnlading', 'ShipmentDestination', 'ShipmentOrigin', 'ShipperPanjivaID']
# Carrier 1032 1.0
# ConsigneePanjivaID 57125 1.0
# HSCode 2962 1.0
# PortOfLading 385 1.0
# PortOfUnlading 60 1.0
# ShipmentDestination 159 1.0
# ShipmentOrigin 191 1.0
# ShipperPanjivaID 69182 1.0
#                 domain  count
# 4       PortOfUnlading     60
# 5  ShipmentDestination    159
# 6       ShipmentOrigin    191
# 3         PortOfLading    385
# 0              Carrier   1032
# 2               HSCode   2962
# 1   ConsigneePanjivaID  57125
# 7     ShipperPanjivaID  69182
# Removing ::
# column :  PortOfUnlading count 20
# column :  ShipmentDestination count 38
# column :  ShipmentOrigin count 49
# column :  PortOfLading count 158
# column :  Carrier count 282
# column :  HSCode count 1425
# column :  ConsigneePanjivaID count 52738
# column :  ShipperPanjivaID count 64985
#  DF length :  238417
#  DF length :  83697
#  >  Carrier : 570
#  >  ConsigneePanjivaID : 3734
#  >  HSCode : 1375
#  >  PortOfLading : 199
#  >  PortOfUnlading : 37
#  >  ShipmentDestination : 110
#  >  ShipmentOrigin : 102
#  >  ShipperPanjivaID : 3915
#  Feature columns ::  ['Carrier', 'ConsigneePanjivaID', 'HSCode', 'PortOfLading', 'PortOfUnlading', 'ShipmentDestination', 'ShipmentOrigin', 'ShipperPanjivaID']
#  dict_DomainDims  {'Carrier': 570, 'ConsigneePanjivaID': 3734, 'HSCode': 1375, 'PortOfLading': 199, 'PortOfUnlading': 37, 'ShipmentDestination': 110, 'ShipmentOrigin': 102, 'ShipperPanjivaID': 3915}
# Length of train data  83697
# DIR :: us_import3  Type :: test Files count:: 1
#  In HSCode clean up , length of dataframe  230249
# size of  Test set  230249
#  Length of testing data 69317
# (        PanjivaRecordID  Carrier  ConsigneePanjivaID  HSCode  PortOfLading  \
#  9             126540927      288                3550    1033           120
#  10            126165823      440                 582    1004           154
#  34            126009279      288                3345    1033           120
#  65            125592255      440                 582    1000           157
#  68            126540991      288                3556    1043           120
#  ...                 ...      ...                 ...     ...           ...
#  956309        126937894      129                 145     460           161
#  956314        127026086      475                 799     314           153
#  956318        126629350      288                2164    1037            92
#  956343        125886438      440                1670     981           156
#  956349        125326310       46                2316    1001            97
#
#          PortOfUnlading  ShipmentDestination  ShipmentOrigin  ShipperPanjivaID  \
#  9                    3                   19               7              3422
#  10                  16                   55              39               295
#  34                   9                   80               7              3240
#  65                  16                   55              38                59
#  68                   3                   19               7              2307
#  ...                ...                  ...             ...               ...
#  956309               9                   37              32              1635
#  956314              30                   82              36              1821
#  956318               9                    5              42              1321
#  956343              16                   55              36              1602
#  956349              27                   78              70               162
#
#          VolumeTEU   WeightKg  ValueOfGoodsUSD
#  9            0.19    890.855          14000.0
#  10           1.50   6095.370         132000.0
#  34           0.26   1541.760          24200.0
#  65           0.64   3701.310          48400.0
#  68           0.09    564.722          10700.0
#  ...           ...        ...              ...
#  956309       1.00  18153.000          73800.0
#  956314       2.00  19894.000          26300.0
#  956318       0.11    531.157          23100.0
#  956343       0.40   1236.950          20100.0
#  956349       0.02     68.000           1700.0
#
#  [83697 rows x 12 columns],
#          PanjivaRecordID  Carrier  ConsigneePanjivaID  HSCode  PortOfLading  \
#  6             126823293      440                3221      87           156
#  30            127412733       46                 545    1221           173
#  37            126805885      288                3345    1046           120
#  44            127442109      288                2001    1043           148
#  54            127734397      288                1508    1043           148
#  ...                 ...      ...                 ...     ...           ...
#  932138        127984704      313                1064    1128           124
#  932146        127734400      288                1508    1033           148
#  932156        127900864       46                 492    1344            39
#  932165        127734464      288                2164    1039            92
#  932167        127733888      288                3338    1046           120
#
#          PortOfUnlading  ShipmentDestination  ShipmentOrigin  ShipperPanjivaID  \
#  6                   16                   55              36                 2
#  30                  22                   87              16              2797
#  37                   3                   19               7              3422
#  44                   9                    5              66              3441
#  54                   9                   37              42              2434
#  ...                ...                  ...             ...               ...
#  932138              35                   26              48              1209
#  932146               9                   37              42              2434
#  932156              34                   52              32              2015
#  932165               9                    5              42              1321
#  932167               9                   37               7              1559
#
#          VolumeTEU   WeightKg  ValueOfGoodsUSD
#  6            1.47  12473.800          47100.0
#  30           0.09    893.000           5900.0
#  37           0.11    483.076          15200.0
#  44           0.31    928.050          17400.0
#  54           0.07    423.655           7900.0
#  ...           ...        ...              ...
#  932138       1.00   8848.000          11500.0
#  932146       0.15    602.824           9400.0
#  932156       0.28   2594.000          98300.0
#  932165       0.08    310.711          20400.0
#  932167       0.09    534.332          16800.0
#
#  [69317 rows x 12 columns],
#  {'Carrier': {'ABPG - Albini & Pitigliani Spa': 0,
#    'ABTB - Albatrans Spa': 1,
#    'ACDF - Acs Lines': 2,
#    'ACGD - Ace Logistics Co Ltd': 3,
#    'ACLU - Atlantic Container Line Ab': 4,
#    'ACUC - Acs Usa Llc': 5,
#    'ACYF - Air City Inc': 6,
#    'ADPR - Adp Global Logistics Inc (Usa)': 7,
#    'AEEG - Ae Eagle Logistics Inc': 8,
#    'AERR - Acme Freight Services Corp': 9,
#    'AGOG - Argos Group Inc': 10,
#    'AIEI - Agriculture Investment Export Inc': 11,
#    'AIHE - Alliance Shipping London': 12,
#    'AIQM - Ami India Logistics Private Limited': 13,
#    'AIRL - Airlift (U S A) Inc': 14,
#    'ALPJ - Allcargo Logistics Limited': 15,
#    'ALRB - Ac Container Line Gmbh': 16,
#    'AMAW - Apex Shipping Co': 17,
#    'AMCI - Architectural Metalcraft Industries Ltd': 18,
#    'AMIG - Amass International Group Inc': 19,
#    'AMLU - Antillean Marine Shipping Corp': 20,
#    'ANIJ - Alliance International': 21,
#    'ANLC - Anl Singapore Pte Ltd': 22,
#    'ANRM - Alianca Navegacao & Logistica Ltda': 23,
#    'APLL - Apl Logistics': 24,
#    'APLU - Apl Co Pte Ltd Nol Group': 25,
#    'APXL - Apex Logistics International Inc': 26,
#    'AQPL - Atlantic Pacific Lines': 27,
#    'AQTY - Ata Freight Line Ltd': 28,
#    'ARRJ - Atlantic Ro Ro Carriers Inc': 29,
#    'ASFN - Asf Global Llc': 30,
#    'ASON - Aso Logistics': 31,
#    'ASQN - Asl Logistics Inc': 32,
#    'ASQR - Astracon': 33,
#    'ASTI - Air Sea Transport Inc': 34,
#    'ASWW - Air Sea Worldwide Logistics Ltd': 35,
#    'ATEB - Ate Logistic Co Ltd': 36,
#    'ATLL - Atlas Line': 37,
#    'ATXF - Air Tiger Express (Asia) Inc': 38,
#    'ATXK - Atx International Srl': 39,
#    'AUIV - Aprile Usa Inc': 40,
#    'AUSR - 1 A Sonic Logistics (Usa) Inc': 41,
#    'AVLC - Arrival Logistics Inc': 42,
#    'AWFD - All Ways Forwarding International Inc': 43,
#    'AWSL - All World Shipping Corp': 44,
#    'AXSM - Ax Supply Chain Management Corp Ltd': 45,
#    'BANQ - Blue Anchor America Line (Blue Anchor Line)': 46,
#    'BARS - Barsan Global Logistics Inc': 47,
#    'BBCY - Bbc Freight Line Inc': 48,
#    'BCGR - Blue Cargo Group Llc (Blu Logistics)': 49,
#    'BGPL - Brilliant Group Logistics Corp': 50,
#    'BMLB - Blue Moon Logistics': 51,
#    'BNTC - Benison Transport Inc': 52,
#    'BNXC - Binex Line Corporation': 53,
#    'BONA - Bona Logistics Us Inc': 54,
#    'BOPT - Bdp Transport, Inc': 55,
#    'BQEG - Blue Eagle Consolidation Gmbh': 56,
#    'BRFD - Besler, E & Co': 57,
#    'BSRD - Bright Star Logistics Inc': 58,
#    'BTDD - Barthco International Inc (Ohl International)': 59,
#    'BVLV - Bon Voyage Logistics Inc': 60,
#    'BWLE - Blue World Line': 61,
#    'BWSS - Blue Water Shipping Us Inc': 62,
#    'BXGC - Bondex Logistics Co Ltd': 63,
#    'CCLL - Cargo Container Line Limited': 64,
#    'CCLT - Casa China Limited': 65,
#    'CCNR - Ccni': 66,
#    'CCSG - Cool Carriers Shipping Usa Inc': 67,
#    'CDCC - Cdc Caribe Inc': 68,
#    'CDHN - Columbia Container Lines Inc': 69,
#    'DMER - Dimerco Express (Usa) Corp': 131,
#    'DMLB - Danmar Lines Ltd (Agents)': 132,
#    'DNCY - Dynamic Network Container Line Ltd': 133,
#    'DOLQ - Dole Ocean Cargo Express': 134,
#    'DSRL - Danesi Usa Inc': 135,
#    'DWCH - Dewell Container Shipping': 136,
#    'DWWL - Dynamic World Wide Logistics Inc': 137,
#    'DXFT - Deltamax Freight System Co Ltd': 138,
#    'EBLA - Eurybia Logistics Inc': 139,
#    'ECCI - Econocaribe Consolidators Inc': 140,
#    'ECGO - 5 Earth Cargo Inc': 141,
#    'ECUD - Ecu Line Ltd': 142,
#    'ECUI - Ecu Line': 143,
#    'ECUW - Ecu Worldwide': 144,
#    'EDML - Edm International Logistics Inc': 145,
#    'EFLR - Efl Container Lines Llc': 146,
#    'EFPD - Expo Freight Private Limited': 147,
#    'EGET - Egetrans Usa Inc': 148,
#    'EGLD - Everise Global Logistics Co Ltd': 149,
#    'EGLV - Evergreen Line': 150,
#    'EILP - Eastrong International Logistic Company': 151,
#    'EIMS - Eimskip Logistics Inc': 152,
#    'EKOI - Esko Inc': 153,
#    'ELCM - Everstar Logistics Co Ltd': 154,
#    'ELII - Ever Leading International Inc': 155,
#    'ELZL - Eumex Line Shenzhen Limited': 156,
#    'EMLT - Em Lines Limited': 157,
#    'EMUI - Emu': 158,
#    'ENCL - Eastern Container Line': 159,
#    'ESCN - Eurasia Container Line': 160,
#    'ESIW - Evangel Shipping Inc': 161,
#    'ESLW - Eagle Shipping Ltd': 162,
#    'ESWW - Eastern Shipping Worldwide Inc': 163,
#    'ETAL - E Top Shipping Co Ltd': 164,
#    'ETIT - E T I Intl Inc': 165,
#    'ETSB - Ets Express Line Ltd': 166,
#    'EUNS - Eunsan Shipping & Aircargo Co Ltd': 167,
#    'EURF - Eurasia Express': 168,
#    'EWLG - East West Logistics Inc': 169,
#    'EXDO - Expeditors International Of Washington Inc': 170,
#    'EXLT - Expelogix (Pvt) Ltd': 171,
#    'EXNW - Excel Network Limited': 172,
#    'EZLO - Ez Logistics Llc': 173,
#    'FAAC - Faircon Line Co Ltd': 174,
#    'FCCJ - Fcc Logistics Inc': 175,
#    'FFPV - Fps Famous Pacific Shipping B V': 176,
#    'FGFQ - Fulltrans Global Lines': 177,
#    'FGIW - Fg International Logistic Ltd': 178,
#    'FGNL - Fastgrow International Co Inc': 179,
#    'FMSW - Fms Seaways Ag': 180,
#    'FOSP - Focus Shipping Corp': 181,
#    'FOXR - Fox Global Logistcs Corp': 182,
#    'FPSK': 183,
#    'FPSL - Fps Logistic (Usa) Inc': 184,
#    'FSGT - Four Season Logistics Corporation': 185,
#    'FSNL - F S International Limited': 186,
#    'FSYT - Freight Systems Inc': 187,
#    'FTHH - Fair Trade Schiffahrt Handel & Logistik Gmbh': 188,
#    'FTNV - Fedex Trade Networks Transport & Brokerage Inc': 189,
#    'FTPA - Fastic Shipping Co Ltd': 190,
#    'GBII - Golden Bridge International Inc': 191,
#    'GCLE - Global Container Line': 192,
#    'GCNL - Gl Container Line': 193,
#    'JTNG - J & T Intl Logistics Co Ltd': 255,
#    'JWTT - Janel World Trade Logistics Of Shenzhen Ltd, The': 256,
#    'KCLG - Korchina Logistics Usa Inc': 257,
#    'KCOH - Keihin Co Ltd, The': 258,
#    'KFUI - King Freight (Usa) Inc': 259,
#    'KGWQ - Kgw Logistics (M) Sdn Bhd': 260,
#    'KILV - Kousa Intl Logistics Co Ltd': 261,
#    'KKLU - Kawasaki Kisen Kaisha Ltd': 262,
#    'KLIL - Kase Logistics International Limited': 263,
#    'KLJC - Kasy Logistics (Tianjin) Co Ltd': 264,
#    'KLLP - Kl Logistic Corporation': 265,
#    'KLNL - Kln Container Line Limited': 266,
#    'KLQI - Kesco Logistics Inc': 267,
#    'KLUS - Delcon Line (Usa) Inc': 268,
#    'KODL - Kodai Company Ltd': 269,
#    'KOSL - King Ocean Services Limited Inc': 270,
#    'KSEV - Krieger Seaservices': 271,
#    'KSHV - King Shipping Company': 272,
#    'KWEO - Kintetsu World Express Inc': 273,
#    'KWLD - Kingwood Logistics Ltd': 274,
#    'KYEP': 275,
#    'LAVR - Lcl': 276,
#    'LCBC - Lcl Lines': 277,
#    'LCSN - Lcs Logistics Inc': 278,
#    'LFFV - Lf Logistics Usa Llc': 279,
#    'LFFW - Laconic Freight International Ltd': 280,
#    'LGFR - Logfret Inc': 281,
#    'LMDL - Lmd Logistics Inc': 282,
#    'LNCF - Leonardi & C Spa': 283,
#    'LPUS - Linea Peninsular Inc': 284,
#    'LSPK - Lsp Line': 285,
#    'LUFR - Laufer Group International Ltd': 286,
#    'LYFW - Longyuan Forwarding Co Ltd': 287,
#    'MAEU - Maersk Line': 288,
#    'MANY - Marathon Line N Y Inc': 289,
#    'MATS - Matson Navigation Co': 290,
#    'MBEL - Marubeni Logistics Corporation': 291,
#    'MBLT - Mb Logistics International Inc': 292,
#    'MCLM - Mcl Multi Container Line Inc': 293,
#    'MCPV - Mac Supply Chain Solutions Private Limited': 294,
#    'MCXV - Mantec Express Limited': 295,
#    'MDNL - Meridian Line': 296,
#    'MFGT - Mainfreight Inc': 297,
#    'MFUS - Marfret Container Lines': 298,
#    'MGIA - Mgl (Usa) Inc': 299,
#    'MIBQ - Maytrans International Corp': 300,
#    'MIDG - Mid America Overseas (Shanghai) Ltd': 301,
#    'MIGC - Master International Logistics (China) Co Ltd': 302,
#    'MIQO - Miq Logistics': 303,
#    'MLCW - Mclean Cargo Specialists (Division Of Crane Worldwide Logistics Llc)': 304,
#    'MLGD - Mol Logistics (Usa) Inc': 305,
#    'MLIL - Maxwide Logistics Inc': 306,
#    'MLIN - Motherlines Inc': 307,
#    'MLQD - Matson Logistics (Shanghai) Co Ltd': 308,
#    'MOLH - Mol Consolidation Service Limited': 309,
#    'MOLU - Mitsui O S K Lines Ltd': 310,
#    'MOXR - Morrison Express Corporation (U S A)': 311,
#    'MPRG - Mprs Shipping & Logistics Pvt Ltd': 312,
#    'MQLA - 4 Mitsubishi Logistics America Corporation': 313,
#    'MQNA - Mac Nels Agencies Pte Ltd': 314,
#    'MRIA - Maritrans Shipping': 315,
#    'SHZS - Seahorse Shipping Corporation': 434,
#    'SIGL - Seamark Internatioinal Logistics Co Ltd': 435,
#    'SILQ - Samskip Logistics Inc': 436,
#    'SINO - Sino Connections Logistics Inc': 437,
#    'SIXL - Scarbrough International Express Lines Ltd': 438,
#    'SLCC - Speedier Logistics Co Ltd': 439,
#    'SMLU - Seaboard Marine Ltd': 440,
#    'SMMB - Seamaster Logistics Inc': 441,
#    'SNTK - Sun Track Express': 442,
#    'SPIL - Speedy International Llc': 443,
#    'SPNP - Shenzhen Pacific Net': 444,
#    'SQST - Seaquest Line': 445,
#    'SRXV': 446,
#    'SSAW - Sea Road International Inc': 447,
#    'SSLL - Saco Shipping Line Limited': 448,
#    'SSLN - Shine Shipping Limited': 449,
#    'SSNF - Shanghai Supreme International Freight Forwarding Co Ltd': 450,
#    'STIW - Sea Trade International Inc': 451,
#    'STND - Sinotrans Limited': 452,
#    'STSW - Sumisho Global Logistics (Usa) Corporation': 453,
#    'SUDU - Hamburg Sued': 454,
#    'SULP - Soma Universal Logistics Private Ltd': 455,
#    'SUPS - Super Trans Lines Inc': 456,
#    'SVAD - Saima Avandero Spa': 457,
#    'SVDL - Savino Del Bene S P A': 458,
#    'SVIS - Savitransport Inc': 459,
#    'SVIV - Shanghai Everest International Logistics Co Ltd': 460,
#    'SVTA - Svt Logistics': 461,
#    'SWGB - Swift Global Line': 462,
#    'SWIJ - Swat International Inc': 463,
#    'SWLC - Seaworld Express Lines Limited': 464,
#    'SWLV - Safewater Lines (India) Private Limited': 465,
#    'SWOE - Seko Worldwide': 466,
#    'SXLM - Sparx Logistics Usa Limited': 467,
#    'SXPK - Sea Big Express Inc': 468,
#    'SYSA - S Y Shipping Corp': 469,
#    'SYUQ - Sankyu Inc': 470,
#    'SZSO - Shenzhen Shining Ocean International Logistics Co Ltd': 471,
#    'TBLW - Transglobal Logistics Inc': 472,
#    'TDGT - Tandem Global Logistics': 473,
#    'TFEN - Transfreight Express Lines': 474,
#    'TFXL - Transfrut Express Limited': 475,
#    'TGBJ - Team Global Logistics Co Ltd': 476,
#    'TGBS - Trans Global Shipping': 477,
#    'TGFH - Toll Global Forwarding (Hong Kong) Limited': 478,
#    'TGLN - Tgl Container Lines Limited': 479,
#    'THGL - T H I Logistics Co Ltd': 480,
#    'TKAS - Takase Add System Inc': 481,
#    'TKIB - Trans Knights Inc': 482,
#    'TLKP - Translink Shipping Inc': 483,
#    'TLLT - Transitainer Llc': 484,
#    'TLYI - Tlss Inc': 485,
#    'TMGB - Team Global Logistics Pvt Ltd': 486,
#    'TMLH - Transamerica Logistic': 487,
#    'TNJI - Tri Net (Japan) Inc': 488,
#    'TOEJ - Trans Orient Express Inc': 489,
#    'TOLC - Tier One Logistics': 490,
#    'TONR - Transcon Shipping Company Inc': 491,
#    'TOPO - Topocean Consolidation Service (Los Angeles) Inc': 492,
#    'TPUL - Three Plus (3 Plus) Logistics': 493,
#    'TQAM - Trans Am Sea Freight (Hk) Ltd': 494,
#    'TRFG - Trust Freight Services Inc': 495,
#    'TRKU - Turkon Container Transportation & Shipping': 496,
#    'TRNH - Trinity Shipping Line S A': 497,
#    'TRUM - Triumph Link Logistics Ltd': 498,
#    'TRXS - Transeas Express (D J Powers Company Inc D/B/A)': 499,
#    'TSCW - Tropical Shipping & Construction Co': 500,
#    'TSIJ - Top Sealand International Co Ltd': 501,
#    'TSJL - Transcontainer Ltd': 502,
#    'TSOC - Tigers Usa Global Logistis Inc': 503,
#    'TSQV - Top Since Logistics Inc': 504,
#    'TSVC - Trans Service Line': 505,
#    'TTWM - Transport Team Worldwide Ltd': 506,
#    'TVLC - T V L Container Line': 507,
#    'TWGD - Transwell Logistics Co Ltd': 508,
#    'TWIC - Trans Wagon Intl Co Ltd': 509,
#    'TWUD - Transworld Shipping (Usa) Inc': 510,
#    'TXMN - Transmodal Corporation': 511,
#    'TYPC - Thornley & Pitt Inc': 512,
#    'TZCL - T Z Cargo Ltd': 513,
#    'UASI - Ups Asia Group Pte Ltd': 514,
#    'UASU - United Arab Shipping Co Sag': 515,
#    'UCMI - United Cargo Management Inc': 516,
#    'UEUR - Ups Europe Sprl': 517,
#    'UHLL - United Harbour Logistics Llc': 518,
#    'ULFM - Ultimate Freight Management, The': 519,
#    'UNPC - Uti United States Inc': 520,
#    'UNPS - Universal Power Shipping Limited': 521,
#    'UNQL - Unique Logistics International (H K) Ltd': 522,
#    'UNSL - Universal Shipping Inc': 523,
#    'UPOF - Ups Ocean Freight Services Inc': 524,
#    'UPSP - Unipac Shipping Inc': 525,
#    'USGQ - United Stone Global Logistics Inc': 526,
#    'USGR - U S Group Consolidator Inc': 527,
#    'USHL - United Shipping Lines': 528,
#    'USIM - U S Intermodal Maritime Inc': 529,
#    'USNL - United Sunfine Logistics': 530,
#    'USSA - U S Shipping Inc': 531,
#    'UULN - Us United Logistics (Ningbo) Inc': 532,
#    'VGLT - Vilden Global Trade Solutions Sdn Bhd': 533,
#    'VHFL - Vantec Hts Forwarding Ltd': 534,
#    'VIOO - Vio Cargo Line': 535,
#    'VNQC - Vinpac Container Line (L A) Inc': 536,
#    'VSTA - Vista Lines': 537,
#    'WBLC - Worldbridge Logistics Inc': 538,
#    'WCTH - W C T Corp': 539,
#    'WCTM - World Cargo Transport Inc': 540,
#    'WDCA - World Consolidators': 541,
#    'WDSB - World Direct Shipping Llc': 542,
#    'WECD - Weida Freight System Co Ltd': 543,
#    'WECS - Wynn Express Corp': 544,
#    'WFSO - Wice Logistics Public Company Limited': 545,
#    'WHLC - Wan Hai Lines Ltd': 546,
#    'WIFW - Westar International Forwarders Lp': 547,
#    'WLBH - Walmay Logistics Inc': 548,
#    'WLIR - W & L International Express Inc': 549,
#    'WLSM - Worldtrans Logistics Services Limited': 550,
#    "WMID - We May Int'l Logistics Co Ltd": 551,
#    'WNAL - Winair Logistics Inc': 552,
#    'WPAK - Waterlink Pakistan (Pvt) Ltd': 553,
#    'WRUS - Weiss Rohlig Usa Llc': 554,
#    'WSAM - Western Shipping America Inc': 555,
#    'WSLT - Winsys Logistics Inc': 556,
